# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
df = pd.read_csv('data/covid_data_136.csv',header=None)
df.drop(0, axis=1, inplace=True)
df.dropna(inplace=True)
df = df.sample(2000)
df
# Out:
#              1         2         3         4         5         6         7   \
# 339    38.25749  48.29364  38.25610  48.29525  38.25647  48.29748  38.25823
# 5409   34.80381  50.60637  34.80239  50.60787  34.80268  50.61003  34.80439
# 2162   32.37614  48.42511  32.37436  48.42460  32.37305  48.42603  32.37352
# 5048   35.98272  50.72758  35.98129  50.72911  35.98159  50.73131  35.98332
# 17964  35.28252  60.26461  35.20525  60.33089  35.21113  60.44526  35.29434
# ...         ...       ...       ...       ...       ...       ...       ...
# 217    36.78493  45.70405  36.78315  45.70355  36.78183  45.70513  36.78229
# 6298   35.81161  51.43070  35.81018  51.43221  35.81046  51.43443  35.81219
# 15288  35.27324  48.67024  35.26353  48.68093  35.26583  48.69588  35.27783
# 2589   31.35123  48.67742  31.34946  48.67691  31.34815  48.67832  31.34863
# 5118   36.03861  50.55145  36.03719  50.55298  36.03749  50.55518  36.03922
#
#              8         9         10        11        12
# 339    48.29811  38.25962  48.29650  38.25925  48.29426
# 5409   50.61069  34.80581  50.60920  34.80552  50.60704
# 2162   48.42798  32.37529  48.42849  32.37660  48.42706
# 5048   50.73199  35.98475  50.73047  35.98445  50.72827
# 17964  60.49363  35.37175  60.42742  35.36582  60.31277
# ...         ...       ...       ...       ...       ...
# 217    45.70722  36.78407  45.70773  36.78539  45.70614
# 6298   51.43513  35.81363  51.43362  35.81334  51.43141
# 15288  48.70013  35.28754  48.68944  35.28524  48.67448
# 2589   48.68024  31.35040  48.68076  31.35170  48.67935
# 5118   50.55586  36.04065  50.55434  36.04034  50.55213
#
# [2000 rows x 12 columns]

# %%
m = folium.Map(location=[32.427910, 53.688046], zoom_start=5, tiles='cartodbpositron')

def my_color_function(feature):
    return 

folium.GeoJson(
    'geojson/iran.geojson',
    style_function=lambda feature: {
        'fillColor': '#fefea0',
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

for index, row in df.iterrows():
    folium.Circle(location=[row[1],row[2]],
                        radius=1,
                        color="red",
                        fill=True).add_to(m)

#mc.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
