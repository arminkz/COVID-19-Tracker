# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
df = pd.read_csv('data/covid_data_134.csv',header=None)
df.drop(0, axis=1, inplace=True)
df.dropna(inplace=True)
df = df.sample(2000)
df
# Out:
#              1         2         3         4         5         6         7   \
# 17814  31.32495  56.66331  31.25209  56.72862  31.25982  56.83394  31.34049
# 11979  34.35105  58.72405  34.34950  58.72541  34.34965  58.72770  34.35134
# 9966   32.23633  54.03536  32.23487  54.03675  32.23508  54.03889  32.23675
# 6477   35.61630  51.48712  35.61487  51.48862  35.61515  51.49083  35.61687
# 13647  36.42543  54.95326  36.41491  54.96358  36.41652  54.97970  36.42865
# ...         ...       ...       ...       ...       ...       ...       ...
# 3369   35.72284  53.35678  35.72137  53.35826  35.72162  53.36051  35.72335
# 8308   35.82336  50.97523  35.82193  50.97675  35.82223  50.97895  35.82395
# 481    36.28396  47.65616  36.28259  47.65772  36.28295  47.65987  36.28467
# 17866  28.49588  53.02153  28.42723  53.08645  28.43647  53.18446  28.51445
# 6209   35.70402  51.45804  35.70258  51.45955  35.70286  51.46176  35.70459
#
#              8         9         10        11        12
# 17814  56.87418  31.41350  56.80889  31.40569  56.70334
# 11979  58.72862  34.35289  58.72725  34.35274  58.72497
# 9966   54.03964  32.23820  54.03824  32.23799  54.03610
# 6477   51.49154  35.61831  51.49003  35.61803  51.48782
# 13647  54.98551  36.43917  54.97519  36.43756  54.95906
# ...         ...       ...       ...       ...       ...
# 3369   53.36127  35.72482  53.35979  35.72457  53.35754
# 8308   50.97964  35.82538  50.97813  35.82509  50.97592
# 481    47.66045  36.28605  47.65889  36.28569  47.65674
# 17866  53.21775  28.58324  53.15282  28.57391  53.05461
# 6209   51.46247  35.70603  51.46096  35.70574  51.45875
#
# [2000 rows x 12 columns]

# %%
m = folium.Map(location=[32.427910, 53.688046], zoom_start=5, tiles='cartodbpositron')

def my_color_function(feature):
    return 

folium.GeoJson(
    'geojson/iran.geojson',
    style_function=lambda feature: {
        'fillColor': '#fefea0',
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

for index, row in df.iterrows():
    folium.Circle(location=[row[1],row[2]],
                        radius=1,
                        color="red",
                        fill=True).add_to(m)

#mc.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
